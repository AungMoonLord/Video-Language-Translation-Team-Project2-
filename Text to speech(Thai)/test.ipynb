# %%
from f5_tts.api import F5TTS

tts = F5TTS(
    model="VIZINTZOR/F5-TTS-THAI",
    device="cuda"  # เปลี่ยนเป็น "cpu" ถ้าไม่มี GPU
)

text = "สวัสดีครับ นี่คือการเริ่มต้นใหม่ทั้งหมด"

tts.tts_to_file(
    text=text,
    file_path="output.wav"
)

print("สร้างไฟล์เสียงเรียบร้อย 🎧")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from f5_tts.api import F5TTS
#       3 tts = F5TTS(
#       4     model="VIZINTZOR/F5-TTS-THAI",
#       5     device="cuda"  # เปลี่ยนเป็น "cpu" ถ้าไม่มี GPU
#       6 )
#       8 text = "สวัสดีครับ นี่คือการเริ่มต้นใหม่ทั้งหมด"
#
# ModuleNotFoundError: No module named 'f5_tts'
