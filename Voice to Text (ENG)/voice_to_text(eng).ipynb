# %% [markdown]
# ใช้โมเดล openai/whisper-large-v3

# %%
# !pip install --upgrade pip
# !pip install --upgrade transformers datasets[audio] accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 32.5 MB/s  0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 31.1 MB/s  0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [datasets]
# ...

# %%
import warnings
from transformers import pipeline
import torch

# %% [markdown]
# voice 1

# %%
# voice1

# 1. ปิดการแสดงผลข้อความเตือน (Warning)
warnings.filterwarnings("ignore")

# ตั้งค่า Device
device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

# โหลดโมเดล
pipe = pipeline(
    "automatic-speech-recognition",
    model="openai/whisper-large-v3",
    torch_dtype=torch_dtype,
    device=device,
)

audio_file_path = "voice1.mp3"

# 2. เปลี่ยน language เป็น "thai" หรือลบออกเพื่อให้มัน Auto-detect
result1 = pipe(
    audio_file_path,
    generate_kwargs={"language": "english"} # เปลี่ยนตรงนี้เป็น thai
)

print("-" * 50)
print(result1["text"])
print("-" * 50)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Device set to use cuda:0
# `return_token_timestamps` is deprecated for WhisperFeatureExtractor and will be removed in Transformers v5. Use `return_attention_mask` instead, as the number of frames can be inferred from it.
# --------------------------------------------------
#  I said remember this moment In the back of my mind The time we stood with our shaking hands The crowds in stands went wild We were the kings and the queens
# --------------------------------------------------

# %% [markdown]
# voice 2

# %%
# voice2

audio_file_path = "voice2.mp3"

# 2. เปลี่ยน language เป็น "thai" หรือลบออกเพื่อให้มัน Auto-detect
result2 = pipe(
    audio_file_path,
    generate_kwargs={"language": "english"} # เปลี่ยนตรงนี้เป็น thai
)

print("-" * 50)
print(result2["text"])
print("-" * 50)
# Out:
# --------------------------------------------------
#  I was all alone with the love of my life. She's got glittered skin, my radiant beam in the night. I don't need no light to see you shine. It's your golden light.
# --------------------------------------------------

# %% [markdown]
# voice 3

# %%
# voice3

audio_file_path = "voice3.mp3"

# 2. เปลี่ยน language เป็น "thai" หรือลบออกเพื่อให้มัน Auto-detect
result3 = pipe(
    audio_file_path,
    generate_kwargs={"language": "english"} # เปลี่ยนตรงนี้เป็น thai
)

print("-" * 50)
print(result3["text"])
print("-" * 50)
# Out:
# --------------------------------------------------
#  i'm gonna trust my heart right now and if it's better to bet on us then i double down and if we end up in bed and i put the covers out and if i'm wrong i just bury my head deep on the ground i gotta know are you feeling the rush if so then i think i know what's going on now we're falling in love say yes or no yes or no yes or no
# --------------------------------------------------

# %% [markdown]
# ใช้โมเดล distil-whisper/distil-large-v3

# %%
# !pip install --upgrade transformers torch accelerate

# %% [markdown]
# voice 1

# %%
# voice1


# ตั้งค่า Device (ถ้ามีการ์ดจอ NVIDIA ให้ใช้ "cuda:0", ถ้าไม่มีใช้ "cpu")
device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

print(f"Loading Model on: {device}...")

# สร้าง Pipeline
# นี่คือทางลัดที่ง่ายที่สุดในการเรียกใช้ model
pipe = pipeline(
    "automatic-speech-recognition",
    model="distil-whisper/distil-large-v3",
    torch_dtype=torch_dtype,
    device=device
)

# ใส่ไฟล์เสียง (เปลี่ยนชื่อไฟล์ตรงนี้เป็นไฟล์ของคุณ)
# รองรับ .mp3, .wav, .mp4 (บางกรณี)
audio_file = "voice1.mp3"

print("Transcribing...")

# สั่งถอดเสียง
# สำคัญมาก! ต้องใส่ return_timestamps=True เพื่อให้รู้เวลาเริ่ม-จบของประโยค
result_1 = pipe(
    audio_file,
    return_timestamps=True,
    generate_kwargs={"language": "english"} # บังคับว่าเป็นภาษาอังกฤษเพื่อความชัวร์
)

# 5. แสดงผลลัพธ์
print("\n--- Full Text ---")
print(result_1["text"])
# Out:
# Loading Model on: cuda:0...
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.51G [00:00<?, ?B/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# Device set to use cuda:0
# Transcribing...
#
# --- Full Text ---
#  I said, remember this moment in the back of my mind, the time we stood with our shaking hands, the crowds in stands went wild, we were the kings and the queens.

# %% [markdown]
# voice 2

# %%
# voice2

# ใส่ไฟล์เสียง (เปลี่ยนชื่อไฟล์ตรงนี้เป็นไฟล์ของคุณ)
# รองรับ .mp3, .wav, .mp4 (บางกรณี)
audio_file = "voice2.mp3"

print("Transcribing...")

# สั่งถอดเสียง
# สำคัญมาก! ต้องใส่ return_timestamps=True เพื่อให้รู้เวลาเริ่ม-จบของประโยค
result_2 = pipe(
    audio_file,
    return_timestamps=True,
    generate_kwargs={"language": "english"} # บังคับว่าเป็นภาษาอังกฤษเพื่อความชัวร์
)

# แสดงผลลัพธ์
print("\n--- Full Text ---")
print(result_2["text"])
# Out:
# Transcribing...
#
# --- Full Text ---
#  I was all alone with the love of my life. She's got glitter for skin, my radiant beaving the night. I don't need no light to see you shine.

# %% [markdown]
# voice 3

# %%
# voice3

# ใส่ไฟล์เสียง (เปลี่ยนชื่อไฟล์ตรงนี้เป็นไฟล์ของคุณ)
# รองรับ .mp3, .wav, .mp4 (บางกรณี)
audio_file = "voice3.mp3"

print("Transcribing...")

# สั่งถอดเสียง
# สำคัญมาก! ต้องใส่ return_timestamps=True เพื่อให้รู้เวลาเริ่ม-จบของประโยค
result_3 = pipe(
    audio_file,
    return_timestamps=True,
    generate_kwargs={"language": "english"} # บังคับว่าเป็นภาษาอังกฤษเพื่อความชัวร์
)

# แสดงผลลัพธ์
print("\n--- Full Text ---")
print(result_3["text"])
# Out:
# Transcribing...
#
# --- Full Text ---
#  I'm gonna trust my heart right now. And if it's better to bed on us then I double down. And if we end up in bed and I put the covers out. And if I'm wrong, I just bury my head deep on the ground. I gotta know. Are you feeling the rush? If so, then I think I know what's going on. Now we're falling in love. Say yes or no, yes or no, yes or no.

# %% [markdown]
# ใช้โมเดล FunAudioLLM/SenseVoiceSmall

# %%
pip install -U funasr modelscope torch torchaudio
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.8/755.8 kB 12.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 34.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 46.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 55.2 MB/s  0:00:00
# ...
#   Created wheel for oss2: filename=oss2-2.19.1-py3-none-any.whl size=124035 sha256=26067b59f7a64040c2fcb09e2f0c918c86cac9767f1e4ff7c2699e49daeb0439
#   Stored in directory: /root/.cache/pip/wheels/a6/aa/ce/a0c9e73f8e4a3b7813b6b0d9dbddfb83028fd416828f27d97b
# ...

# %% [markdown]
# voice 1

# %%
# voice1
import re
from funasr import AutoModel
import torch

# 1. ฟังก์ชันล้าง Tags (เหมือนเดิม)
def clean_sensevoice_text(text):
    clean_text = re.sub(r'<\|.*?\|>', '', text)
    return clean_text.strip()

# 2. โหลดโมเดล SenseVoice
print("⏳ Loading SenseVoice...")
model = AutoModel(
    model="iic/SenseVoiceSmall",
    trust_remote_code=True,
    device="cuda:0" if torch.cuda.is_available() else "cpu"
)

# 3. ระบุไฟล์เสียง
audio_file = "voice1.mp3" # <-- แก้ชื่อไฟล์ตรงนี้

# 4. เริ่มถอดเสียง
print(f"▶ Processing: {audio_file}")
res = model.generate(
    input=audio_file,
    cache={},
    language="auto",
    use_itn=True,
    batch_size_s=60,
)

# 5. ดึงข้อความและล้างให้สะอาด
raw_text = res[0]['text']
final_text = clean_sensevoice_text(raw_text)

print("\n--- Final English Text ---")
print(final_text)
# Out:
# ⏳ Loading SenseVoice...
# funasr version: 1.2.9.
# Check update of funasr, and it would cost few times. You may disable it by set `disable_update=True` in AutoModel
# You are using the latest version of funasr-1.2.9
# ...
# 2025-12-24 01:52:50,934 - modelscope - INFO - Got 19 files, start to download ...
# Processing 19 items:   0%|          | 0.00/19.0 [00:00<?, ?it/s]
# ...
# 2025-12-24 01:53:13,806 - modelscope - INFO - Download model 'iic/SenseVoiceSmall' successfully.
# WARNING:root:trust_remote_code: True
# Loading remote code failed: model, No module named 'model'
# ▶ Processing: voice1.mp3
# rtf_avg: 0.029: 100%|██████████| 1/1 [00:00<00:00,  1.25it/s]
# --- Final English Text ---
# I said remember this moment in the back of my mind, the time we stood with our shaking hands, the crowds and stands went wild we were the kings and the queens.

# %% [markdown]
# voice 2

# %%
# voice2

# ระบุไฟล์เสียง
audio_file = "voice2.mp3" # <-- แก้ชื่อไฟล์ตรงนี้

# 4. เริ่มถอดเสียง
print(f"▶ Processing: {audio_file}")
res = model.generate(
    input=audio_file,
    cache={},
    language="auto",
    use_itn=True,
    batch_size_s=60,
)

# 5. ดึงข้อความและล้างให้สะอาด
raw_text = res[0]['text']
final2_text = clean_sensevoice_text(raw_text)

print("\n--- Final English Text ---")
print(final2_text)
# Out:
# ▶ Processing: voice2.mp3
# rtf_avg: 0.009: 100%|██████████| 1/1 [00:00<00:00,  3.68it/s]
# --- Final English Text ---
# I was all alone with the love of my life, She's got clear up for skin my f and bit the night I don't need know like to see you shy It's your good.

# %% [markdown]
# voice 3

# %%
# voice3

# ระบุไฟล์เสียง
audio_file = "voice3.mp3" # <-- แก้ชื่อไฟล์ตรงนี้

# 4. เริ่มถอดเสียง
print(f"▶ Processing: {audio_file}")
res = model.generate(
    input=audio_file,
    cache={},
    language="auto",
    use_itn=True,
    batch_size_s=60,
)

# 5. ดึงข้อความและล้างให้สะอาด
raw_text = res[0]['text']
final3_text = clean_sensevoice_text(raw_text)

print("\n--- Final English Text ---")
print(final3_text)
# Out:
# ▶ Processing: voice3.mp3
# rtf_avg: 0.009: 100%|██████████| 1/1 [00:00<00:00,  4.25it/s]
# --- Final English Text ---
# I'm gonna chase my heart right now and it is better to be on as day I double down and if we end up being bad end up put the car and if I wrong I just bury my head on the ground I gotta know are you feeling the rush If so that I think I know what going on now we're falling in love saying yes or no yes or no yes or no.

# %% [markdown]
# voice 1

# %%
print("openai/whisper-large-v3")
print(result1["text"])
print()
print("distil-whisper/distil-large-v3")
print(result_1["text"])
print()
print("FunAudioLLM/SenseVoiceSmall")
print(final_text)
# Out:
# openai/whisper-large-v3
#  I said remember this moment In the back of my mind The time we stood with our shaking hands The crowds in stands went wild We were the kings and the queens
#
# distil-whisper/distil-large-v3
#  I said, remember this moment in the back of my mind, the time we stood with our shaking hands, the crowds in stands went wild, we were the kings and the queens.
#
# FunAudioLLM/SenseVoiceSmall
# I said remember this moment in the back of my mind, the time we stood with our shaking hands, the crowds and stands went wild we were the kings and the queens.

# %% [markdown]
# voice 2

# %%
print("openai/whisper-large-v3")
print(result2["text"])
print()
print("distil-whisper/distil-large-v3")
print(result_2["text"])
print()
print("FunAudioLLM/SenseVoiceSmall")
print(final2_text)
# Out:
# openai/whisper-large-v3
#  I was all alone with the love of my life. She's got glittered skin, my radiant beam in the night. I don't need no light to see you shine. It's your golden light.
#
# distil-whisper/distil-large-v3
#  I was all alone with the love of my life. She's got glitter for skin, my radiant beaving the night. I don't need no light to see you shine.
#
# FunAudioLLM/SenseVoiceSmall
# I was all alone with the love of my life, She's got clear up for skin my f and bit the night I don't need know like to see you shy It's your good.

# %% [markdown]
# voice 3

# %%
print("openai/whisper-large-v3")
print(result3["text"])
print()
print("distil-whisper/distil-large-v3")
print(result_3["text"])
print()
print("FunAudioLLM/SenseVoiceSmall")
print(final3_text)
# Out:
# openai/whisper-large-v3
#  i'm gonna trust my heart right now and if it's better to bet on us then i double down and if we end up in bed and i put the covers out and if i'm wrong i just bury my head deep on the ground i gotta know are you feeling the rush if so then i think i know what's going on now we're falling in love say yes or no yes or no yes or no
#
# distil-whisper/distil-large-v3
#  I'm gonna trust my heart right now. And if it's better to bed on us then I double down. And if we end up in bed and I put the covers out. And if I'm wrong, I just bury my head deep on the ground. I gotta know. Are you feeling the rush? If so, then I think I know what's going on. Now we're falling in love. Say yes or no, yes or no, yes or no.
#
# FunAudioLLM/SenseVoiceSmall
# ...
