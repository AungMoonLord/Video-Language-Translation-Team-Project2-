# %%
from moviepy import VideoFileClip

#โหลด Vdo
vide   deoFileClip('Video1.mp4')

#แยกไฟล์เสียงจาก Vdo เป็น mp3
video.audio.write_audiofile('audio_ori.mp3')

#ปิด Vdo
video.close()
# Out:
# MoviePy - Writing audio in audio_ori.mp3
# MoviePy - Done.

# %%
from moviepy import VideoFileClip, AudioFileClip

#โหลด Vdo
video = VideoFileClip('Video1.mp4')

#โหลดเสียงใหม่เข้ามา พร้อมทำให้ความยาวเสียงใหม่ไม่ยาวเกินวิดีโอ
new_audio = AudioFileClip('audio_ori.mp3').subclip(0, video.duration)

#แทนเสียงใหม่ใน Vdo
final = video.set_audio(new_audio)

# export เป็นไฟล์จริง
final.write_videofile(
    'Vdo_new_audio.mp4',
    codec='libx264', # ตัวเข้ารหัสเสียง (Audio Codec)
    audio_codec='aac' # มาตรฐานเสียงของ mp4
)

#ปิด Vdo, audio
video.close()
new_audio.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 7
#       4 video = VideoFileClip('Video1.mp4')
#       6 #โหลดเสียงใหม่เข้ามา พร้อมทำให้ความยาวเสียงใหม่ไม่ยาวเกินวิดีโอ
# ----> 7 new_audio = AudioFileClip('audio_ori.mp3').subclip(0, video.duration)
#       9 #แทนเสียงใหม่ใน Vdo
#      10 final = video.set_audio(new_audio)
#
# AttributeError: 'AudioFileClip' object has no attribute 'subclip'
