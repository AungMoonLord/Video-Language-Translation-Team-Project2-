# %%
from transformers import pipeline

# เลือกใช้ NLLB-200 เพราะคุณภาพสมดุลที่สุด
model_name = "facebook/nllb-200-distilled-600M"

translator = pipeline(
    "translation", 
    model=model_name, 
    device=0 # ใส่ 0 ถ้ามี GPU ,-1 ถ้าใช้ CPU
)

text = "Artificial Intelligence is transforming the world we live in."

# สำหรับ NLLB ต้องระบุ src_lang และ tgt_lang
output = translator(text, src_lang="eng_Latn", tgt_lang="tha_Thai")

print(output[0]['translation_text'])
# ผลลัพธ์: ปัญญาประดิษฐ์กำลังเปลี่ยนแปลงโลกที่เราอาศัยอยู่

# %%
import torch
print(f"Is CUDA available?: {torch.cuda.is_available()}")
print(f"Device name: {torch.cuda.get_device_name(0)}")
print(f"CUDA version PyTorch is using: {torch.version.cuda}")
# Out:
# Is CUDA available?: True
# Device name: NVIDIA GeForce RTX 5060 Ti
# CUDA version PyTorch is using: 12.4

# %%
paragraph1 = "Ais found herself in darkness, not knowing where she was or why she was there. As she looked around, she realized she had transformed back into her younger self, and she felt lonely. Suddenly, her childhood toys appeared as her friends: sister dolls, a plush wolf, a soldier, a light elf, and a cat-shaped soldier, all offering her companionship. Feeling brave, Ais declared herself an adventurer, picked up a toy sword and shield, and began her adventure with her friends."

# %%
paragraph2 = "Together, they faced a dim labyrinth filled with monsters, but Ais felt unafraid. With the help of her small friends, they defeated the monsters one by one. Fairies illuminated their path with colorful magic. Ais swung her sword and managed to defeat the monsters, leading her friends in joyful song and dance as they marched deeper into the labyrinth."

# %%
paragraph3 = "They descended deeper and deeper, down sixty levels, until a cold wind blew. Something wet and sticky splattered on Ais, and when she opened her eyes, she found silence. Turning around, she was horrified to see a crimson spring where her friends lay twisted and injured. Their arms and legs were disfigured, and some were beyond recognition, their stuffing spilling out like entrails. The warm substance on Ais was revealed to be blood — her friends' blood."

# %%
text2 = paragraph1 + paragraph2 + paragraph3

# สำหรับ NLLB ต้องระบุ src_lang และ tgt_lang
output = translator(text2, src_lang="eng_Latn", tgt_lang="tha_Thai")

print(output[0]['translation_text'])
# ผลลัพธ์: ปัญญาประดิษฐ์กำลังเปลี่ยนแปลงโลกที่เราอาศัยอยู่
# Out:
# Your input_length: 327 is bigger than 0.9 * max_length: 200. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 text2 = paragraph1 + paragraph2 + paragraph3
#       3 # สำหรับ NLLB ต้องระบุ src_lang และ tgt_lang
# ----> 4 output = translator(text2, src_lang="eng_Latn", tgt_lang="tha_Thai")
#       6 print(output[0]['translation_text'])
#       7 # ผลลัพธ์: ปัญญาประดิษฐ์กำลังเปลี่ยนแปลงโลกที่เราอาศัยอยู่
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\transformers\pipelines\text2text_generation.py:410, in TranslationPipeline.__call__(self, *args, **kwargs)
#     380 def __call__(self, *args, **kwargs):
#     381     r"""
#     382     Translate the text(s) given as inputs.
#     383
#    (...)
#     408           token ids of the translation.
#     409     """
# --> 410     return super().__call__(*args, **kwargs)
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\transformers\pipelines\text2text_generation.py:191, in Text2TextGenerationPipeline.__call__(self, *args, **kwargs)
#     162 def __call__(self, *args: Union[str, list[str]], **kwargs: Any) -> list[dict[str, str]]:
#     163     r"""
#     164     Generate the output text(s) using text(s) given as inputs.
#     165
#    (...)
#     188           ids of the generated text.
#     189     """
# --> 191     result = super().__call__(*args, **kwargs)
#     192     if (
#     193         isinstance(args[0], list)
#     194         and all(isinstance(el, str) for el in args[0])
#     195         and all(len(res) == 1 for res in result)
#     196     ):
#     197         return [res[0] for res in result]
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\transformers\pipelines\base.py:1467, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1459     return next(
#    1460         iter(
#    1461             self.get_iterator(
#    (...)
#    1464         )
#    1465     )
#    1466 else:
# -> 1467     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\transformers\pipelines\base.py:1474, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1472 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1473     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1474     model_outputs = self.forward(model_inputs, **forward_params)
#    1475     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1476     return outputs
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\transformers\pipelines\base.py:1374, in Pipeline.forward(self, model_inputs, **forward_params)
#    1372     with inference_context():
#    1373         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1374         model_outputs = self._forward(model_inputs, **forward_params)
#    1375         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1376 else:
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\transformers\pipelines\text2text_generation.py:220, in Text2TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     217 if "generation_config" not in generate_kwargs:
#     218     generate_kwargs["generation_config"] = self.generation_config
# --> 220 output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     221 out_b = output_ids.shape[0]
#     222 if self.framework == "pt":
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\transformers\generation\utils.py:2564, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2561 model_kwargs["use_cache"] = generation_config.use_cache
#    2563 # 9. Call generation mode
# -> 2564 result = decoding_method(
#    2565     self,
#    2566     input_ids,
#    2567     logits_processor=prepared_logits_processor,
#    2568     stopping_criteria=prepared_stopping_criteria,
#    2569     generation_config=generation_config,
#    2570     **generation_mode_kwargs,
#    2571     **model_kwargs,
#    2572 )
#    2574 # Convert to legacy cache format if requested
#    2575 if (
#    2576     generation_config.return_legacy_cache is True
#    2577     and hasattr(result, "past_key_values")
#    2578     and getattr(result.past_key_values, "to_legacy_cache") is not None
#    2579 ):
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\transformers\generation\utils.py:3265, in GenerationMixin._beam_search(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    3262 flat_running_sequences = self._flatten_beam_dim(running_sequences[:, :, :cur_len])
#    3263 model_inputs = self.prepare_inputs_for_generation(flat_running_sequences, **model_kwargs)
# -> 3265 model_outputs = self(**model_inputs, return_dict=True)
#    3267 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3268 model_kwargs = self._update_model_kwargs_for_generation(
#    3269     model_outputs,
#    3270     model_kwargs,
#    3271     is_encoder_decoder=self.config.is_encoder_decoder,
#    3272 )
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\transformers\models\m2m_100\modeling_m2m_100.py:1419, in M2M100ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1397         decoder_input_ids = shift_tokens_right(
#    1398             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1399         )
#    1401 outputs = self.model(
#    1402     input_ids,
#    1403     attention_mask=attention_mask,
#    (...)
#    1417     cache_position=cache_position,
#    1418 )
# -> 1419 lm_logits = self.lm_head(outputs[0])
#    1421 masked_lm_loss = None
#    1422 if labels is not None:
#    1423     # move labels to the correct device to enable PP
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\aungl\anaconda3\envs\product\lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
